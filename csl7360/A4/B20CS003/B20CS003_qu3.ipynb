# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !unzip /content/DeerFinder.v4i.yolov5pytorch.zip
# Out:
# Archive:  /content/DeerFinder.v4i.yolov5pytorch.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/3_png.rf.5b51070668c22bdbf448edf60a26abff.jpg
#  extracting: test/images/deer-2_jpg.rf.5e0c0d3ce056eb4d70453c8e2f840d4d.jpg
#  extracting: test/images/deer-8_jpg.rf.f9d091a0b5fe0a13dd3e022c2876c0be.jpg
#    creating: test/labels/
#  extracting: test/labels/3_png.rf.5b51070668c22bdbf448edf60a26abff.txt
#  extracting: test/labels/deer-2_jpg.rf.5e0c0d3ce056eb4d70453c8e2f840d4d.txt
#  extracting: test/labels/deer-8_jpg.rf.f9d091a0b5fe0a13dd3e022c2876c0be.txt
#    creating: train/
#    creating: train/images/
#  extracting: train/images/4_JPG.rf.29e715ef34bc1d428f1c263f5ff7d96e.jpg
#  extracting: train/images/4_JPG.rf.56c114746788924865a4dd902a210b89.jpg
#  extracting: train/images/4_JPG.rf.c97b47451a81ed8d7e900f866939388e.jpg
# ...

# %% [markdown]
# # Train

# %%
# !python train.py --img 448 --batch 1 --epochs 200 --data /content/yolov5/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=1, imgsz=448, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # Validate

# %%
# !python val.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --data /content/yolov5/data.yaml --img 448 --verbose
# Out:
# val: data=/content/yolov5/data.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=448, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/yolov5/valid/labels.cache... 3 images, 0 backgrounds, 0 corrupt: 100% 3/3 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.37it/s]
#                    all          3         23      0.344      0.632      0.603      0.342
# ...

# %% [markdown]
# # Detect

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 448 --conf 0.25 --source /content/yolov5/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/yolov5/test/images, data=data/coco128.yaml, imgsz=[448, 448], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-158-g8211a03 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3 /content/yolov5/test/images/3_png.rf.5b51070668c22bdbf448edf60a26abff.jpg: 448x448 2 deers, 4 not-deers, 7.2ms
# image 2/3 /content/yolov5/test/images/deer-2_jpg.rf.5e0c0d3ce056eb4d70453c8e2f840d4d.jpg: 448x448 1 deer, 7.3ms
# ...
